# %%
from encode_versaoAlunos import *

# %%
a = Encode()
a.main()
# Out:
# --->Inicializando encoder
#
# --->Aguardando usuário...
# Digite aqui um tecla de 0 a 9 que você quer simular:
# 9
# Frequencia 1: 1477
# Frequência 2: 852
# Gerando Tons base
# Executando as senoides (emitindo o som)
# Gerando Tom referente ao símbolo : 9
# -->Gerando gráfico da frequência 1
# -->Gerando gráfico da frequência 2
# -->Gerando gráfico da frequência combinada
# Picos são:
# Pico 1: 1477.0
# Pico 2: 852.0
