# %%
from decode_versaoAlunos import *

# %%
a = Decode()
a.main()
# Out:
# --->Inicializando decoder
#
# -->Gravação irá se iniciar em 3s...
#
# -->Gravação Iniciada
#
# -->Gravação encerrada
#
# -->Áudio gravado
